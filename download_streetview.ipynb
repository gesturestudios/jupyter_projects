# %% [markdown]
# # Street view extraction for use in SfM
# This notebook uses the google maps and street view APIs to download street view images between two points with location information identified, and map the resulting points.  The images extracted can be used for Structure from Motion terrain modeling, and the image coordinates can be used as ground control points to georeference the model.

# %%
# Import the libraries that we will use in this notebook:
import gmaps, math, urllib, os, json, google_streetview.api
api_key = "your api key"    # Set the API key
gmaps.configure(api_key=api_key)                       # Configure gmaps to use our API key
DownLoc = r'C:\Users\Cemodo\Documents\Python_projects\Coulee_street_view\downloads' # location to save files

# First, we set a fwe beginning parameters:
start_location = [47.829407, -119.133617]
end_location = [47.817773, -119.151449]

# make a guess of the approximate bearing to the next point on the road
rough_direction = 225  # !!not bearing, but direction in degrees but with horizontal origin,
# increasing counter-clockwise like in trig!!
# (my head almost explode thinking about how to convert from map bearing to trig direction... 
# I gave up because it really didn't matter, we just need to pick something that works to get out next point.)
# (I'm sure someone has already figured it out on the internet somewhere... but I didn't go find it.)
# cheat sheet: 0=East, 90=North, 180=West, 270=South
approx_disp = 50 # distance in feet, approximately, between street view images.
heading = 120  # bearing we want to look, holding this constant because the cliff is basically linear and constant.

print('done')
# Out:
# done

# %%
# so to do this, we need some maths...  and trigonometry- so pulling out the old SOHCAHTOA!
deg_to_mi = 69 # at this latitude, there is roughly 69 miles to a degree.  This is approximate and should be fine here.
mi_to_ft = 5280 # conversion factor from miles to feet.
disp_deg = round(approx_disp / (mi_to_ft * deg_to_mi),7) # Calculate the approximate displacement in degrees 
y_disp = round(math.sin(math.pi * rough_direction /180)*disp_deg,7) # Calculate the y component of displacement
x_disp = round(math.cos(math.pi * rough_direction /180)*disp_deg,7) # Calculate the x component of displacement
check = round(math.sqrt((x_disp*x_disp)+(y_disp*y_disp)),7)         # Check our math: a^2 + b^2 = c^2
print("approx displacement in degrees is: "+str(disp_deg))
print('x disp = ' + str(x_disp) + '... y disp = ' + str(y_disp))
print('math check = '+str(check))
# Out:
# approx displacement in degrees is: 0.0001372
# x disp = -9.7e-05... y disp = -9.7e-05
# math check = 0.0001372

# %%
# Now let's plot our starting location and end location and view the line we want to extract photos from on a map
fig = gmaps.figure()
extraction_route = gmaps.directions_layer(start_location, end_location)
fig.add_layer(extraction_route)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# The functions below were copied and modified from here: 
# https://andrewpwheeler.com/2018/04/02/drawing-google-streetview-images-down-an-entire-street-using-python/
key = "&key=" + api_key  # text API key for using with the street view API
# define functions...
def MetaParse(MetaUrl):
    '''Function to parse out the URL response'''
    response = urllib.request.urlopen(MetaUrl)
    jsonRaw = response.read()
    jsonData = json.loads(jsonRaw)
    #return jsonData
    if jsonData['status'] == "OK":
        return (jsonData['pano_id'],jsonData['location']['lat'],jsonData['location']['lng'])
    else:
        return (None,None,None)
        
def GetStreetLL(Lat,Lon,Head,File,SaveLoc):
    '''Funciton to create the URL and give it to the street view API'''
    base = r"https://maps.googleapis.com/maps/api/streetview"
    size = r"?size=640x640&location="
    end = str(Lat) + "," + str(Lon) + "&heading=" + str(Head) + key
    MyUrl = base + size + end
    fi = File + ".jpg"
    MetaUrl = base + r"/metadata" + size + end
    #print MyUrl, MetaUrl #can check out image in browser to adjust size, fov to needs
    met_lis = list(MetaParse(MetaUrl))
    
    if (met_lis[0],Head) not in PrevImage:   #PrevImage is global list
        urllib.request.urlretrieve(MyUrl, os.path.join(SaveLoc,fi))
        met_lis.append(fi)
        PrevImage.append((met_lis[0],Head)) #append new Pano ID to list of images
    else:
        met_lis.append(None)
    return met_lis

# %%
# Make some data containers to keep information returned from the API:
PrevImage = []        # Global list that has previous images sampled
points_returned = []  # list of all finalized points returned

# find if the start location has an assoicated street view, and it's coordinates:
temp = GetStreetLL(start_location[0],start_location[1],Head=heading,File='Test_origin',SaveLoc=DownLoc)
if temp[3] is not None:  # if this came back with a photo, then good, we will keep that photo, and...
    origy = temp[1]      # keep the y coordinate returned for that photo for later use
    origx = temp[2]      # keep the x coordinate returned for that photo for later use
    #points_returned.append([origy,origx])
    print('There is a photo here, saving to folder.')
# print the results of this:
print('temp list: '+str(temp))
print('previous image: '+str(PrevImage))
print('points returned: '+str(points_returned))
# Out:
# There is a photo here, saving to folder.
# temp list: ['1YKdzRtdiST6TNqgtmQvzQ', 47.82944653171898, -119.1337098570937, 'Test_origin.jpg']
# previous image: [('1YKdzRtdiST6TNqgtmQvzQ', 120)]
# points returned: []

# %%
# make a point of displacement
def next_point_guess(lat,long,approx_disp,rough_direction):
    '''This function is used to make a guess at the next point along our path
    inputs:
    lat, long: input starting latitude and longitude (int)
    approx_disp: displacement in feet that we think we should go to the next point (int)
    rough_direction: direction in radial degrees we think the next point should be
    output:
    newlat, newlong: calculated new latitude and longitude'''
    disp_deg = round(approx_disp / (mi_to_ft * deg_to_mi),7)            # calculate the input displacement in feet
    y_disp = round(math.sin(math.pi * rough_direction /180)*disp_deg,7) # calculate the y component of displacement
    x_disp = round(math.cos(math.pi * rough_direction /180)*disp_deg,7) # calculate the x component of displacement
    newlat = lat + y_disp     # the new latitude 
    newlong = long + x_disp   # the new longitude
    return (newlat,newlong)   # values to return

# %%
# now lets guess where the next street view point might be..
nexty,nextx = next_point_guess(origy,origx,approx_disp,rough_direction)  # make a guess
temp = GetStreetLL(nexty,nextx,Head=heading,File='Test_second',SaveLoc=DownLoc) # get the street view at that point
if temp[3] is not None: # if we got a new point (the ID wasn't already in the list of previous points) then it worked...
    rety = temp[1] 
    retx = temp[2]
    #points_returned.append([rety,retx])
    print('We have the next point, saving.')
else:
    print('That was too close to the original, try a bit more distance')
# print the results of this:
print('temp list: '+str(temp))
print('previous image: '+str(PrevImage))
print('points returned: '+str(points_returned))
# Out:
# We have the next point, saving.
# temp list: ['paZi5h8KnYUc2TR_u9FXXA', 47.82937046581372, -119.1337716766599, 'Test_second.jpg']
# previous image: [('1YKdzRtdiST6TNqgtmQvzQ', 120), ('paZi5h8KnYUc2TR_u9FXXA', 120)]
# points returned: []

# %%
# re-adjust the bearing and distance using a function:
def adjust_disp_bearing(origy,rety,origx,retx,rough_direction):
    '''Calculate the displacement and bearing from the previous 2 points'''
    y_diff = origy - rety
    x_diff = origx - retx
    disp = round(math.sqrt((y_diff ** 2)+(x_diff ** 2)) * mi_to_ft * deg_to_mi,0)
    new_direction = round(math.atan2(y_diff,x_diff) * 180 / math.pi,0)
    if rough_direction - new_direction > 90:
        new_direction = new_direction + 180
    return (disp,new_direction)
# run the function
approx_disp,new_direction = adjust_disp_bearing(origy,rety,origx,retx,rough_direction)
points_returned.append([rety,retx,approx_disp,new_direction])
# check what the new distance and bearing are
print('new distance is ' + str(approx_disp))
print('new bearing is '+str(new_direction))
print('points returned: '+str(points_returned))
# Out:
# new distance is 36.0
# new bearing is 231.0
# points returned: [[47.82937046581372, -119.1337716766599, 36.0, 231.0]]

# %%
# now let's see how far we are from the destination point- we can use the same function:
dis2dest,dest_direction = adjust_disp_bearing(nexty,end_location[0],nextx,end_location[1],rough_direction)
print('distance to destionation is about ' + str(dis2dest) + ' feet or ' + str(round(dis2dest/mi_to_ft,1)) + ' miles')
print('bearing is ' + str(dest_direction))
# Out:
# distance to destionation is about 7701.0 feet or 1.5 miles
# bearing is 213.0

# %%
# ok, now we can put it all together into a loop that looks down the road for the next point, confirms or adjusts to try again...

counter = 0           # start the counter at 0, to see how many frames we collect in all
countermax = 100      # set a max of 100 to start with- don't want to wind up with a crazy Google API bill this month...
while (counter < countermax and dis2dest > 2000):
    print('The count is:' + str(counter))
    counter = counter + 1        # step up the counter
    origy = nexty                # make the last returned y the origin
    origx = nextx                # make the last returned x the origin
    nexty,nextx = next_point_guess(origy,origx,approx_disp,new_direction)   # calculate the next point along the road
    temp = GetStreetLL(nexty,nextx,Head=heading,File='file'+str(counter).zfill(5),SaveLoc=DownLoc)
    if temp[3] is not None:
        rety = temp[1]
        retx = temp[2]
        print('We have the next point, saving as ' + temp[3])
        approx_disp,new_direction = adjust_disp_bearing(origy,rety,origx,retx,rough_direction)
        points_returned.append([rety,retx,approx_disp,new_direction])
        reset = 1
    elif reset < 3:
        print('That was too close to the original, trying a bit more distance')
        approx_disp = approx_disp/2 + approx_disp
        reset = reset + 1
    else: 
        counter = 100
    print(str(approx_disp))
    print(str(new_direction))
    dis2dest,dest_direction = adjust_disp_bearing(nexty,end_location[0],nextx,end_location[1],rough_direction)
    print('distance to destionation is about ' + str(dis2dest) + ' feet or ' + str(dis2dest/mi_to_ft) + ' miles')
print('done')
# Out:
# The count is:0
# We have the next point, saving as file00001.jpg
# 37.0
# 236.0
# distance to destionation is about 7667.0 feet or 1.4520833333333334 miles
# The count is:1
# We have the next point, saving as file00002.jpg
# 38.0
# 235.0
# distance to destionation is about 7633.0 feet or 1.4456439393939393 miles
# The count is:2
# We have the next point, saving as file00003.jpg
# 35.0
# 230.0
# distance to destionation is about 7598.0 feet or 1.4390151515151515 miles
# The count is:3
# We have the next point, saving as file00004.jpg
# 34.0
# 225.0
# distance to destionation is about 7564.0 feet or 1.4325757575757576 miles
# The count is:4
# We have the next point, saving as file00005.jpg
# 36.0
# 225.0
# distance to destionation is about 7531.0 feet or 1.4263257575757575 miles
# The count is:5
# We have the next point, saving as file00006.jpg
# 40.0
# 230.0
# distance to destionation is about 7496.0 feet or 1.4196969696969697 miles
# The count is:6
# We have the next point, saving as file00007.jpg
# 37.0
# 236.0
# distance to destionation is about 7457.0 feet or 1.412310606060606 miles
# The count is:7
# We have the next point, saving as file00008.jpg
# 35.0
# 236.0
# distance to destionation is about 7424.0 feet or 1.406060606060606 miles
# The count is:8
# We have the next point, saving as file00009.jpg
# 35.0
# 230.0
# distance to destionation is about 7391.0 feet or 1.3998106060606061 miles
# The count is:9
# We have the next point, saving as file00010.jpg
# 35.0
# 225.0
# distance to destionation is about 7358.0 feet or 1.393560606060606 miles
# The count is:10
# We have the next point, saving as file00011.jpg
# 37.0
# 226.0
# distance to destionation is about 7324.0 feet or 1.3871212121212122 miles
# The count is:11
# We have the next point, saving as file00012.jpg
# 39.0
# 232.0
# distance to destionation is about 7288.0 feet or 1.3803030303030304 miles
# The count is:12
# We have the next point, saving as file00013.jpg
# 36.0
# 236.0
# distance to destionation is about 7251.0 feet or 1.3732954545454545 miles
# The count is:13
# We have the next point, saving as file00014.jpg
# 33.0
# 234.0
# distance to destionation is about 7218.0 feet or 1.3670454545454545 miles
# The count is:14
# We have the next point, saving as file00015.jpg
# 34.0
# 228.0
# distance to destionation is about 7188.0 feet or 1.3613636363636363 miles
# The count is:15
# We have the next point, saving as file00016.jpg
# 38.0
# 225.0
# distance to destionation is about 7155.0 feet or 1.3551136363636365 miles
# The count is:16
# We have the next point, saving as file00017.jpg
# 30.0
# 227.0
# distance to destionation is about 7118.0 feet or 1.3481060606060606 miles
# The count is:17
# We have the next point, saving as file00018.jpg
# 30.0
# 233.0
# distance to destionation is about 7089.0 feet or 1.3426136363636363 miles
# The count is:18
# We have the next point, saving as file00019.jpg
# 37.0
# 235.0
# distance to destionation is about 7061.0 feet or 1.3373106060606061 miles
# The count is:19
# We have the next point, saving as file00020.jpg
# 40.0
# 233.0
# distance to destionation is about 7027.0 feet or 1.330871212121212 miles
# The count is:20
# We have the next point, saving as file00021.jpg
# 41.0
# 229.0
# distance to destionation is about 6990.0 feet or 1.3238636363636365 miles
# The count is:21
# We have the next point, saving as file00022.jpg
# 38.0
# 226.0
# distance to destionation is about 6951.0 feet or 1.3164772727272727 miles
# The count is:22
# We have the next point, saving as file00023.jpg
# 34.0
# 227.0
# distance to destionation is about 6914.0 feet or 1.309469696969697 miles
# The count is:23
# We have the next point, saving as file00024.jpg
# 29.0
# 232.0
# distance to destionation is about 6881.0 feet or 1.303219696969697 miles
# The count is:24
# We have the next point, saving as file00025.jpg
# 33.0
# 236.0
# distance to destionation is about 6854.0 feet or 1.2981060606060606 miles
# The count is:25
# We have the next point, saving as file00026.jpg
# 41.0
# 235.0
# distance to destionation is about 6824.0 feet or 1.2924242424242425 miles
# The count is:26
# We have the next point, saving as file00027.jpg
# 41.0
# 231.0
# distance to destionation is about 6787.0 feet or 1.2854166666666667 miles
# The count is:27
# We have the next point, saving as file00028.jpg
# 37.0
# 226.0
# distance to destionation is about 6749.0 feet or 1.278219696969697 miles
# The count is:28
# We have the next point, saving as file00029.jpg
# 33.0
# 226.0
# distance to destionation is about 6713.0 feet or 1.2714015151515152 miles
# The count is:29
# We have the next point, saving as file00030.jpg
# 31.0
# 232.0
# distance to destionation is about 6681.0 feet or 1.2653409090909091 miles
# The count is:30
# We have the next point, saving as file00031.jpg
# 36.0
# 235.0
# distance to destionation is about 6652.0 feet or 1.2598484848484848 miles
# The count is:31
# We have the next point, saving as file00032.jpg
# 42.0
# 233.0
# distance to destionation is about 6619.0 feet or 1.253598484848485 miles
# The count is:32
# We have the next point, saving as file00033.jpg
# 43.0
# 229.0
# distance to destionation is about 6581.0 feet or 1.246401515151515 miles
# The count is:33
# We have the next point, saving as file00034.jpg
# 39.0
# 226.0
# distance to destionation is about 6540.0 feet or 1.2386363636363635 miles
# The count is:34
# We have the next point, saving as file00035.jpg
# 33.0
# 227.0
# distance to destionation is about 6503.0 feet or 1.231628787878788 miles
# The count is:35
# We have the next point, saving as file00036.jpg
# 31.0
# 232.0
# distance to destionation is about 6471.0 feet or 1.2255681818181818 miles
# The count is:36
# We have the next point, saving as file00037.jpg
# 35.0
# 235.0
# distance to destionation is about 6442.0 feet or 1.2200757575757575 miles
# The count is:37
# We have the next point, saving as file00038.jpg
# 41.0
# 233.0
# distance to destionation is about 6411.0 feet or 1.2142045454545454 miles
# The count is:38
# We have the next point, saving as file00039.jpg
# 44.0
# 229.0
# distance to destionation is about 6373.0 feet or 1.2070075757575758 miles
# The count is:39
# We have the next point, saving as file00040.jpg
# 39.0
# 224.0
# distance to destionation is about 6331.0 feet or 1.1990530303030302 miles
# The count is:40
# We have the next point, saving as file00041.jpg
# 33.0
# 221.0
# distance to destionation is about 6294.0 feet or 1.1920454545454546 miles
# The count is:41
# We have the next point, saving as file00042.jpg
# 32.0
# 224.0
# distance to destionation is about 6261.0 feet or 1.1857954545454545 miles
# The count is:42
# We have the next point, saving as file00043.jpg
# 37.0
# 230.0
# distance to destionation is about 6231.0 feet or 1.1801136363636364 miles
# The count is:43
# We have the next point, saving as file00044.jpg
# 43.0
# 232.0
# distance to destionation is about 6196.0 feet or 1.1734848484848486 miles
# The count is:44
# We have the next point, saving as file00045.jpg
# 41.0
# 229.0
# distance to destionation is about 6156.0 feet or 1.165909090909091 miles
# The count is:45
# We have the next point, saving as file00046.jpg
# 37.0
# 221.0
# distance to destionation is about 6118.0 feet or 1.1587121212121212 miles
# The count is:46
# We have the next point, saving as file00047.jpg
# 35.0
# 215.0
# distance to destionation is about 6082.0 feet or 1.1518939393939394 miles
# The count is:47
# We have the next point, saving as file00048.jpg
# 36.0
# 219.0
# distance to destionation is about 6047.0 feet or 1.1452651515151515 miles
# The count is:48
# We have the next point, saving as file00049.jpg
# 40.0
# 227.0
# distance to destionation is about 6012.0 feet or 1.1386363636363637 miles
# The count is:49
# We have the next point, saving as file00050.jpg
# 40.0
# 232.0
# distance to destionation is about 5974.0 feet or 1.1314393939393939 miles
# The count is:50
# We have the next point, saving as file00051.jpg
# 40.0
# 225.0
# distance to destionation is about 5937.0 feet or 1.1244318181818183 miles
# The count is:51
# We have the next point, saving as file00052.jpg
# 40.0
# 214.0
# distance to destionation is about 5899.0 feet or 1.1172348484848484 miles
# The count is:52
# We have the next point, saving as file00053.jpg
# 41.0
# 209.0
# distance to destionation is about 5859.0 feet or 1.1096590909090909 miles
# The count is:53
# We have the next point, saving as file00054.jpg
# 40.0
# 215.0
# distance to destionation is about 5818.0 feet or 1.1018939393939393 miles
# The count is:54
# We have the next point, saving as file00055.jpg
# 40.0
# 227.0
# distance to destionation is about 5778.0 feet or 1.0943181818181817 miles
# The count is:55
# We have the next point, saving as file00056.jpg
# 39.0
# 232.0
# distance to destionation is about 5740.0 feet or 1.0871212121212122 miles
# The count is:56
# We have the next point, saving as file00057.jpg
# 38.0
# 225.0
# distance to destionation is about 5705.0 feet or 1.0804924242424243 miles
# The count is:57
# We have the next point, saving as file00058.jpg
# 39.0
# 213.0
# distance to destionation is about 5669.0 feet or 1.0736742424242425 miles
# The count is:58
# We have the next point, saving as file00059.jpg
# 40.0
# 209.0
# distance to destionation is about 5630.0 feet or 1.066287878787879 miles
# The count is:59
# We have the next point, saving as file00060.jpg
# 39.0
# 216.0
# distance to destionation is about 5590.0 feet or 1.058712121212121 miles
# The count is:60
# We have the next point, saving as file00061.jpg
# 39.0
# 225.0
# distance to destionation is about 5551.0 feet or 1.0513257575757575 miles
# The count is:61
# We have the next point, saving as file00062.jpg
# 40.0
# 225.0
# distance to destionation is about 5514.0 feet or 1.044318181818182 miles
# The count is:62
# We have the next point, saving as file00063.jpg
# 41.0
# 217.0
# distance to destionation is about 5476.0 feet or 1.037121212121212 miles
# The count is:63
# We have the next point, saving as file00064.jpg
# 41.0
# 208.0
# distance to destionation is about 5435.0 feet or 1.0293560606060606 miles
# The count is:64
# We have the next point, saving as file00065.jpg
# 41.0
# 206.0
# distance to destionation is about 5395.0 feet or 1.021780303030303 miles
# The count is:65
# We have the next point, saving as file00066.jpg
# 40.0
# 213.0
# distance to destionation is about 5354.0 feet or 1.0140151515151514 miles
# The count is:66
# We have the next point, saving as file00067.jpg
# 40.0
# 222.0
# distance to destionation is about 5314.0 feet or 1.0064393939393939 miles
# The count is:67
# We have the next point, saving as file00068.jpg
# 40.0
# 224.0
# distance to destionation is about 5275.0 feet or 0.9990530303030303 miles
# The count is:68
# We have the next point, saving as file00069.jpg
# 40.0
# 217.0
# distance to destionation is about 5237.0 feet or 0.9918560606060606 miles
# The count is:69
# We have the next point, saving as file00070.jpg
# 41.0
# 208.0
# distance to destionation is about 5197.0 feet or 0.984280303030303 miles
# The count is:70
# We have the next point, saving as file00071.jpg
# 42.0
# 204.0
# distance to destionation is about 5156.0 feet or 0.9765151515151516 miles
# The count is:71
# We have the next point, saving as file00072.jpg
# 42.0
# 207.0
# distance to destionation is about 5114.0 feet or 0.968560606060606 miles
# The count is:72
# We have the next point, saving as file00073.jpg
# 42.0
# 214.0
# distance to destionation is about 5073.0 feet or 0.9607954545454546 miles
# The count is:73
# We have the next point, saving as file00074.jpg
# 41.0
# 218.0
# distance to destionation is about 5031.0 feet or 0.9528409090909091 miles
# The count is:74
# We have the next point, saving as file00075.jpg
# 39.0
# 216.0
# distance to destionation is about 4991.0 feet or 0.9452651515151516 miles
# The count is:75
# We have the next point, saving as file00076.jpg
# 41.0
# 208.0
# distance to destionation is about 4952.0 feet or 0.9378787878787879 miles
# The count is:76
# We have the next point, saving as file00077.jpg
# 40.0
# 204.0
# distance to destionation is about 4911.0 feet or 0.9301136363636363 miles
# The count is:77
# We have the next point, saving as file00078.jpg
# 41.0
# 207.0
# distance to destionation is about 4871.0 feet or 0.9225378787878787 miles
# The count is:78
# We have the next point, saving as file00079.jpg
# 44.0
# 214.0
# distance to destionation is about 4830.0 feet or 0.9147727272727273 miles
# The count is:79
# We have the next point, saving as file00080.jpg
# 42.0
# 217.0
# distance to destionation is about 4787.0 feet or 0.9066287878787879 miles
# The count is:80
# We have the next point, saving as file00081.jpg
# 37.0
# 211.0
# distance to destionation is about 4745.0 feet or 0.8986742424242424 miles
# The count is:81
# We have the next point, saving as file00082.jpg
# 42.0
# 202.0
# distance to destionation is about 4708.0 feet or 0.8916666666666667 miles
# The count is:82
# We have the next point, saving as file00083.jpg
# 48.0
# 200.0
# distance to destionation is about 4666.0 feet or 0.8837121212121212 miles
# The count is:83
# We have the next point, saving as file00084.jpg
# 50.0
# 206.0
# distance to destionation is about 4619.0 feet or 0.874810606060606 miles
# The count is:84
# We have the next point, saving as file00085.jpg
# 45.0
# 214.0
# distance to destionation is about 4569.0 feet or 0.8653409090909091 miles
# The count is:85
# We have the next point, saving as file00086.jpg
# 38.0
# 216.0
# distance to destionation is about 4524.0 feet or 0.8568181818181818 miles
# The count is:86
# We have the next point, saving as file00087.jpg
# 35.0
# 207.0
# distance to destionation is about 4487.0 feet or 0.8498106060606061 miles
# The count is:87
# We have the next point, saving as file00088.jpg
# 41.0
# 198.0
# distance to destionation is about 4452.0 feet or 0.8431818181818181 miles
# The count is:88
# We have the next point, saving as file00089.jpg
# 49.0
# 199.0
# distance to destionation is about 4411.0 feet or 0.8354166666666667 miles
# The count is:89
# We have the next point, saving as file00090.jpg
# 51.0
# 206.0
# distance to destionation is about 4363.0 feet or 0.8263257575757575 miles
# The count is:90
# We have the next point, saving as file00091.jpg
# 46.0
# 214.0
# distance to destionation is about 4312.0 feet or 0.8166666666666667 miles
# The count is:91
# We have the next point, saving as file00092.jpg
# 37.0
# 215.0
# distance to destionation is about 4266.0 feet or 0.8079545454545455 miles
# The count is:92
# We have the next point, saving as file00093.jpg
# 35.0
# 201.0
# distance to destionation is about 4229.0 feet or 0.8009469696969697 miles
# The count is:93
# We have the next point, saving as file00094.jpg
# 44.0
# 191.0
# distance to destionation is about 4194.0 feet or 0.7943181818181818 miles
# The count is:94
# We have the next point, saving as file00095.jpg
# 53.0
# 195.0
# distance to destionation is about 4152.0 feet or 0.7863636363636364 miles
# The count is:95
# We have the next point, saving as file00096.jpg
# 53.0
# 205.0
# distance to destionation is about 4100.0 feet or 0.7765151515151515 miles
# The count is:96
# We have the next point, saving as file00097.jpg
# 45.0
# 215.0
# distance to destionation is about 4047.0 feet or 0.7664772727272727 miles
# The count is:97
# We have the next point, saving as file00098.jpg
# 40.0
# 214.0
# distance to destionation is about 4003.0 feet or 0.7581439393939394 miles
# The count is:98
# We have the next point, saving as file00099.jpg
# 37.0
# 197.0
# distance to destionation is about 3963.0 feet or 0.7505681818181819 miles
# The count is:99
# We have the next point, saving as file00100.jpg
# 44.0
# 185.0
# distance to destionation is about 3927.0 feet or 0.74375 miles
# done

# %%
print('points returned:')
points_returned
# Out:
# points returned:
# [[47.82937046581372, -119.1337716766599, 36.0, 231.0],
#  [47.82929186733913, -119.1338367759438, 37.0, 236.0],
#  [47.82921326886454, -119.1339018752277, 38.0, 235.0],
#  [47.8291425302374, -119.1339604645831, 35.0, 230.0],
#  [47.8290639317628, -119.134025563867, 34.0, 225.0],
#  [47.82898533328821, -119.1340906631509, 36.0, 225.0],
#  [47.82890673481361, -119.1341557624348, 40.0, 230.0],
#  [47.82883599618648, -119.1342143517903, 37.0, 236.0],
#  [47.8287573977119, -119.1342794510742, 35.0, 236.0],
#  [47.8286787992373, -119.1343445503581, 35.0, 230.0],
#  [47.8286056904439, -119.1344045779804, 35.0, 225.0],
#  [47.82852674522195, -119.1344687389902, 37.0, 226.0],
#  [47.8284478, -119.1345329, 39.0, 232.0],
#  [47.82837521915164, -119.134593768387, 36.0, 236.0],
#  [47.82830099072647, -119.134655771813, 33.0, 234.0],
#  [47.82822242203735, -119.1347209495092, 34.0, 228.0],
#  [47.82814385334822, -119.1347861272054, 38.0, 225.0],
#  [47.82808885526583, -119.1348317515927, 30.0, 227.0],
#  [47.82801028657671, -119.1348969292888, 30.0, 233.0],
#  [47.82793171788759, -119.134962106985, 37.0, 235.0],
#  [47.82786100606737, -119.1350207669115, 40.0, 233.0],
#  [47.82778243737825, -119.1350859446077, 41.0, 229.0],
#  [47.82770386868912, -119.1351511223038, 38.0, 226.0],
#  [47.8276253, -119.1352163, 34.0, 227.0],
#  [47.82755470926622, -119.1352739915273, 29.0, 232.0],
#  [47.82747565594446, -119.1353378550571, 33.0, 236.0],
#  [47.8273966026227, -119.1354017185868, 41.0, 235.0],
#  [47.82732545463311, -119.1354591957636, 41.0, 231.0],
#  [47.82724640131134, -119.1355230592934, 37.0, 226.0],
#  [47.82716734798959, -119.1355869228232, 33.0, 226.0],
#  [47.82709240791195, -119.1356475479812, 31.0, 232.0],
#  [47.82701385270413, -119.1357127601571, 36.0, 235.0],
#  [47.82693529749631, -119.1357779723331, 42.0, 233.0],
#  [47.82685674228848, -119.135843184509, 43.0, 229.0],
#  [47.82677818708066, -119.135908396685, 39.0, 226.0],
#  [47.82669963187284, -119.135973608861, 33.0, 227.0],
#  [47.82662107666502, -119.1360388210369, 31.0, 232.0],
#  [47.82654252145721, -119.1361040332129, 35.0, 235.0],
#  [47.82646396624938, -119.1361692453888, 41.0, 233.0],
#  [47.82638541104157, -119.1362344575648, 44.0, 229.0],
#  [47.82631263517154, -119.1363007993983, 39.0, 224.0],
#  [47.82623644432021, -119.1363719627864, 33.0, 221.0],
#  [47.82616025346887, -119.1364431261745, 32.0, 224.0],
#  [47.82608406261754, -119.1365142895626, 37.0, 230.0],
#  [47.82600787176621, -119.1365854529507, 43.0, 232.0],
#  [47.82593806774755, -119.136650760312, 41.0, 229.0],
#  [47.82586393147254, -119.1367265847381, 37.0, 221.0],
#  [47.82578979519753, -119.1368024091642, 35.0, 215.0],
#  [47.82571565892252, -119.1368782335904, 36.0, 219.0],
#  [47.82564152264751, -119.1369540580165, 40.0, 227.0],
#  [47.82557343735109, -119.1370239118147, 40.0, 232.0],
#  [47.82550301212059, -119.1371072145779, 40.0, 225.0],
#  [47.82543258689009, -119.1371905173412, 40.0, 214.0],
#  [47.8253621616596, -119.1372738201045, 41.0, 209.0],
#  [47.82529173642909, -119.1373571228677, 40.0, 215.0],
#  [47.82522178976858, -119.1374398634326, 40.0, 227.0],
#  [47.82515284834967, -119.1375214109493, 39.0, 232.0],
#  [47.82508391268748, -119.1376029513717, 38.0, 225.0],
#  [47.82501508185542, -119.1376843675117, 39.0, 213.0],
#  [47.82494665279965, -119.1377653064078, 40.0, 209.0],
#  [47.824877650745, -119.137846926233, 39.0, 216.0],
#  [47.82481233905362, -119.1379315239325, 39.0, 225.0],
#  [47.82474748338353, -119.1380193770967, 40.0, 225.0],
#  [47.82468261956794, -119.1381072409843, 41.0, 217.0],
#  [47.82461824255275, -119.1381945757425, 41.0, 208.0],
#  [47.82455505541396, -119.1382851464059, 41.0, 206.0],
#  [47.82449198818988, -119.1383755448653, 40.0, 213.0],
#  [47.82442889708737, -119.1384659772297, 40.0, 222.0],
#  [47.82436569778267, -119.1385565643644, 40.0, 224.0],
#  [47.82430256743262, -119.1386470523404, 40.0, 217.0],
#  [47.82423943977553, -119.1387375358356, 41.0, 208.0],
#  [47.82418019672696, -119.1388312228441, 42.0, 204.0],
#  [47.82412219269625, -119.138927141794, 42.0, 207.0],
#  [47.82406289180066, -119.139025209557, 42.0, 214.0],
#  [47.82400415810772, -119.1391223367105, 41.0, 218.0],
#  [47.82394765418704, -119.1392157723003, 39.0, 216.0],
#  [47.82388746849421, -119.1393153000611, 41.0, 208.0],
#  [47.82383330137066, -119.1394048750458, 40.0, 204.0],
#  [47.82377311567782, -119.1395044028066, 41.0, 207.0],
#  [47.82371292998499, -119.1396039305674, 44.0, 214.0],
#  [47.82365902385137, -119.1396957657507, 42.0, 217.0],
#  [47.8236088, -119.1397903, 37.0, 211.0],
#  [47.82354904529263, -119.1399026829312, 42.0, 202.0],
#  [47.82349321338577, -119.1400076881036, 48.0, 200.0],
#  [47.82343738147891, -119.1401126932759, 50.0, 206.0],
#  [47.82338172944429, -119.1402173604061, 45.0, 214.0],
#  [47.82332936657829, -119.1403209984003, 38.0, 216.0],
#  [47.82327746023923, -119.1404261753733, 35.0, 207.0],
#  [47.82322543258601, -119.1405315977567, 41.0, 198.0],
#  [47.8231734590148, -119.1406369101489, 49.0, 199.0],
#  [47.82312138216376, -119.1407424314064, 51.0, 206.0],
#  [47.82306931011944, -119.1408479425166, 46.0, 214.0],
#  [47.82301913284439, -119.140954154329, 37.0, 215.0],
#  [47.82297174333147, -119.1410650493749, 35.0, 201.0],
#  [47.82292438915088, -119.1411758612887, 44.0, 191.0],
#  [47.82287694709476, -119.141286878384, 53.0, 195.0],
#  [47.82282952513047, -119.1413978480102, 53.0, 205.0],
#  [47.82278203087489, -119.1415089863475, 45.0, 215.0],
#  [47.822731, -119.1416284, 40.0, 214.0],
#  [47.82269102847644, -119.1417354566741, 37.0, 197.0],
#  [47.82264845449155, -119.1418494908526, 44.0, 185.0]]

# %%
print(str(rety)+','+str(retx))
# Out:
# 47.82332936657829,-119.1403209984003

# %%
plotpoints = []
for i in range(len(points_returned)):
    readline = points_returned[i]
    plotpoints.append((readline[0],readline[1]))
#print(plotpoints)
symbols = gmaps.symbol_layer(plotpoints, fill_color='red', stroke_color='red')
fig.add_layer(symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
